# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="llama-3.1-8b-instant",
    model_provider="groq",
)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant."),
        ("human", "{input}")
    ]
)

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()

chain = prompt | model | parser

response = chain.invoke({"input": "What is Machine Learing"})

print(response)
# Out:
# Machine learning is a subset of artificial intelligence (AI) that involves training algorithms to learn from data, make decisions, and improve their performance over time without being explicitly programmed. It's a key technology that enables machines to interpret, analyze, and make predictions or decisions based on complex data.
#
# Machine learning is based on the idea that machines can learn from experience and adapt to new situations, much like humans do. It involves the use of algorithms that can discover patterns, relationships, and insights in data, and make predictions or decisions based on that data.
#
# There are several key characteristics of machine learning:
#
# 1. **Autonomy**: Machine learning algorithms can operate independently, without human intervention.
# 2. **Learning**: Machine learning algorithms can learn from data and improve their performance over time.
# 3. **Improvement**: Machine learning algorithms can adapt to new data and improve their performance accordingly.
# 4. **Flexibility**: Machine learning algorithms can be applied to a wide range of applications, from image and speech recognition to natural language processing and predictive analytics.
#
# Machine learning is typically categorized into three types:
#
# 1. **Supervised Learning**: In this type of learning, the algorithm is trained on labeled data, where the correct output is already known. The algorithm learns to make predictions or decisions based on the labeled data.
# 2. **Unsupervised Learning**: In this type of learning, the algorithm is trained on unlabeled data, where the correct output is not known. The algorithm learns to identify patterns or relationships in the data.
# 3. **Reinforcement Learning**: In this type of learning, the algorithm is trained through trial and error, where it receives feedback in the form of rewards or penalties for its actions.
#
# Machine learning has many applications, including:
#
# 1. **Image and speech recognition**: Machine learning algorithms can be used to recognize objects, faces, and speech patterns.
# 2. **Natural language processing**: Machine learning algorithms can be used to understand and generate human language.
# 3. **Predictive analytics**: Machine learning algorithms can be used to forecast future events or behavior based on historical data.
# 4. **Recommendation systems**: Machine learning algorithms can be used to recommend products or services based on user preferences.
#
# Some common machine learning techniques include:
#
# 1. **Decision Trees**: Decision trees are a type of supervised learning algorithm that use a tree-like model to make predictions or decisions.
# 2. **Random Forests**: Random forests are an ensemble learning technique that combines multiple decision trees to improve accuracy and reduce bias.
# 3. **Support Vector Machines (SVMs)**: SVMs are a type of supervised learning algorithm that use a kernel trick to classify data into different categories.
# 4. **Neural Networks**: Neural networks are a type of machine learning algorithm that are inspired by the structure and function of the human brain.
#
# I hope this helps you understand machine learning better! Let me know if you have any further questions.
