# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    "llama-3.1-8b-instant",
    model_provider="groq"
)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_template(
    """Generate 20 interview questions based on {topic}"""
)
parser = StrOutputParser()
chain = prompt |model| parser

response = chain.invoke({"topic": "Spring Boot"})
print(response)
# Out:
# Here are 20 interview questions based on Spring Boot:
#
# **Section 1: Spring Boot Fundamentals**
#
# 1. What is Spring Boot, and how does it differ from the traditional Spring Framework?
# 2. What is the purpose of the `application.properties` file in a Spring Boot application?
# 3. How do you configure logging in a Spring Boot application?
# 4. What is the difference between `@Configuration` and `@Bean` annotations in Spring Boot?
# 5. How do you enable security in a Spring Boot application?
#
# **Section 2: Spring Boot Features**
#
# 6. What is the purpose of the `@EnableAutoConfiguration` annotation in Spring Boot?
# 7. How do you use the `@Value` annotation to inject properties into a Spring Boot application?
# 8. What is the purpose of the `@ConfigurationProperties` annotation in Spring Boot?
# 9. How do you use Spring Boot's built-in support for database connectivity?
# 10. What is the purpose of the `@Scheduled` annotation in Spring Boot?
#
# **Section 3: Spring Boot and Web Development**
#
# 11. How do you create a RESTful API using Spring Boot?
# 12. What is the purpose of the `@RestController` annotation in Spring Boot?
# 13. How do you use Spring Boot's built-in support for websockets?
# 14. What is the purpose of the `@GetMapping` and `@PostMapping` annotations in Spring Boot?
# 15. How do you handle exceptions in a Spring Boot web application?
#
# **Section 4: Spring Boot and Testing**
#
# 16. How do you write unit tests for a Spring Boot application?
# 17. What is the purpose of the `@RunWith(SpringRunner.class)` annotation in Spring Boot testing?
# 18. How do you use Spring Boot's built-in support for integration testing?
# 19. What is the purpose of the `@SpringBootTest` annotation in Spring Boot testing?
# 20. How do you use Spring Boot's built-in support for mock testing?
#
# Note that these questions cover a range of topics, from fundamentals to advanced features, and are intended to assess a candidate's knowledge and experience with Spring Boot.
