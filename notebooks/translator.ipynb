# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="llama-3.1-8b-instant",
    model_provider="groq",
)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that translates user text into specified {language}."),
    ("user", "{input}")
])

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

chain = prompt | model | parser

chain.invoke({
    "input": "Hello, how are you?",
    "language": "kannada"
})
# Out:
# "ನಮಸ್ಕಾರ, ನೀವು ಯಾವುದೇ ಸಮಸ್ಯೆ ಹೊಂದಿದ್ದೀರಾ? (Namaskara, Neevu yaavudhe samasye hondideera?) \n\n(Note: This is a common way to greet in Kannada. I've translated your message into Kannada as well.)\n\nನಿಮ್ಮಿಂದ  (Nimmindi) = Hello \nನಾನು  (Naanu) = I\nಯೋಗ್ಯ (Yoogy) = How are you\nಇದು ಸರಿ ( idu sari) = I am fine.\n\nನಾನು  ಬಾಕಿ  ಸರಿ.  (Naanu baaki sari) = I am good."
